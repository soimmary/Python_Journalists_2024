# %% [markdown]
# # Семинар 8. Практика

# %% [markdown]
# ## А8 НЭ
#
# Дан фрагмент программы:
#
#     [1] def mail(string):
#     [2]     if '@' in string:
#     [3]         return True
#     [4]     return False
#     [5]
#     [6] def list_address(text):
#     [7]     list_final = []
#     [8]     for address in text.split():
#     [9]         if mail(address):
#     [10]             list_final.append(text)
#     [11]         return list_final
#     [12]
#     [13] text_new = 'borisov belov@yan.ru rukov.com sobakov@df.com'
#     [14] print(list_address(text_new))
#
# Программа выше должна выводить:
#
# `['belov@yan.ru', 'sobakov@df.com']`
#
# Выберите все причины (минимум две), по которым код не будет работать как ожидается.
#
# Важно! Номера в квадратных скобках не являются частью программы и просто обозначают порядковый номер строки.
#
# * В строке [4] перед return не прописано условие
# * В строке [10] в список добавляется вся строка с адресами, а не один адрес
# * В строке [11] сделан лишний отступ перед return
# * В строке [6] неверно выбрано имя аргумента: должно быть text_new
# * Функция mail() определена до основной функции list_address()

# %% [markdown]
# ## А8 НЭ
#
# Дан фрагмент программы:
#
#      [1] def clear_text(word):
#      [2]     word = word.strip(',.!?')
#      [3]     return word
#      [4]
#      [5] def text_ok(string):
#      [6]     string = string.split()
#      [7]     for i in range(len(string)):
#      [8]         string[i] = clear_text(string[i])
#      [9]         string = string[i].lower()
#     [10]     return string.join(',')
#     [11]
#     [12] text = 'Привет! Как дела? Хорошо...'
#     [13] print(text_ok(text))
#
# Программа выше должна выводить:
#
# `'привет,как,дела,хорошо'`
#
# Выберите все причины (минимум две), по которым код не будет работать как ожидается.
#
# Важно! Номера в квадратных скобках не являются частью программы и просто обозначают порядковый номер строки.
#
# * В строке [9] изменяется весь список, а не его отдельный элемент
# * В строке [10] лишний отступ перед return
# * В строке [13] аргументом функции text_ok должна быть строка string
# * В строке [10] неправильно применен метод .join()
# * В строке [6] функции split() не передан аргумент

# %% [markdown]
# ##  B7 НЭ
#
# Реализуйте программу, которая добавляет новый элемент в множество:
#
# Определите функцию add_city, которая принимает два аргумента:
# *  cities — множество названий городов (строки), которое всегда содержит минимум одно значение;
# * new_city — название нового города (строка).
#
# Функция добавляет new_city в множество cities, сортирует его в алфавитном порядке и возвращает список.
#
# Ввод \
# `{'Гранц', 'Вена', 'Линц'}, 'Филлах'` \
# Результат \
# `['Вена', 'Гранц', 'Линц', 'Филлах']`
#
# Ввод \
# `{'Филлах'}, 'Филлах'` \
# Результат \
# `['Филлах']`

# %% [markdown]
# ## B7 НЭ
#
# Реализуйте программу, которая делает из слов их сокращения.
# Определите функцию short_word, которая принимает два аргумента:
# * список words, содержащий в себе список слов, для которых нужно получить сокращения;
# * количество букв count, которое нужно брать с конца слова.
#
# Если в слове не менее 6 букв, то функция убирает у него с конца буквы в количестве, равном count. \
# Если в слове менее 6 букв — функция оставляет только первую букву \
# Функция возвращает список с преобразованными словами.
#
# Для примера:
#
# Ввод	\
# `['полотенце','суп','стол','пятница'], 3 ` \
# Результат \
# `['полоте', 'с', 'с', 'пятн']`
#
# Ввод \
# `['ночь','суп','стол','кот'], 1` \
# Результат \
# `['н', 'с', 'с', 'к']`

# %% [markdown]
# ### C3 НЭ
#
# Сотрудникам трактира полагается 30 дней отпуска в год. Владелец трактира ведет учет, записывая в книгу имена сотрудников и число использованных дней отпуска.
#
# Напишите функцию, которая выводит имена сотрудников, у которых еще остались дни отпуска.
#
# ТРЕБУЕМАЯ ФУНКЦИЯ
#
# * Функция remaining_days принимает на вход два списка:
#   * в первом списке содержатся имена сотрудников (строки);
#   * во втором — соответствующее количество использованных каждым из них дней отпуска (целые числа).
# * Функция должна возвращать список сотрудников, у которых остались неиспользованные дни отпуска (т.е. использованных дней меньше 30).
# * Имена сотрудников должны идти в том же порядке, что и в оригинальном списке.
# * При отсутствии таких сотрудников функция возвращает пустой список.
#
# Для примера:
#
# Ввод \
# `['Юра', 'Люда', 'Кирилл', 'Никита', 'Оля'], [24, 28, 29, 26, 30]` \
# Результат \
# `['Юра', 'Люда', 'Кирилл', 'Никита']`
#
# Ввод \
# `['Катя', 'Влад', 'Витя', 'Денис', 'Петя'], [32, 28, 30, 36, 37]` \
# Результат \
# `['Влад']`
#
# Ввод \
# `['Витя', 'Паша', 'Сережа', 'Слава', 'Валера'], [30, 33, 32, 38, 37]` \
# Результат \
# `[]`

# %%
# ваш код

# %% [markdown]
# ## С3 НЭ
#
# Витя записывает данные о своих друзьях в каждой стране. Напишите функцию, которая определяет, в скольки странах проживают люди с именем, которое интересует Витю.
#
# ТРЕБУЕМАЯ ФУНКЦИЯ
#
# * Функция get_contact, параметрами которой являются:
#   * словарь, где ключи — названия стран (строки), а значения — списки с именам друзей Вити из этих стран (списки строк).
#   * имя человека (строка), для которого нужно проверить, из какой он страны.
# * Функция должна возвращать количество стран, в которых живут знакомые Вити с указанным именем.
# * Если таких стран нет, то функция возвращает 0.
#
# Для примера:
#
# Ввод	\
# `{
# 'UK': ['Alice', 'Alex', 'Rita'],
# 'Austria': ['Ann', 'Sia', 'Alex', 'Rick'],
# 'Germany': ['Nikita', 'Alice', 'Rob', 'Ann'],
# 'USA': ['Liza', 'Margo', 'Ann', 'Alex'],
# 'Russia': ['Rita', 'Ann', 'Liza', 'Ann']
# }, 'Ann'` \
# Результат \
# `4`
#
# Ввод \
# `{
# 'UK': ['Alice', 'Alex', 'Rita'],
# }, 'Alex'` \
# Результат \
# `1`
#
# Ввод \
# `{
# 'UK': ['Alice', 'Alex', 'Alex', 'Rita'],
# 'Austria': ['Ann', 'Sia', 'Alex', 'Rick'],
# 'Russia': ['Rita', 'Liza', 'Ann']
# }, 'Ura'` \
# Результат \
# `0`

# %% [markdown]
# ## Практика по созданию функций

# %% [markdown]
# 1. Напишите функцию, которая принимает в качестве аргумента строку и возвращает строку типа: В строке <строка> <кол-во> символов

# %% [markdown]
# 2. Напишите функцию, которая принимает в качестве аргумента список чисел и возвращает квадрат наибольшего числа в списке.

# %% [markdown]
# 3. Напишите функцию, которая принимает в качестве аргумента список строк и возвращает новый список, содержащий только строки, начинающиеся с буквы "A".

# %% [markdown]
# 4. Напишите функцию, которая принимает в качестве аргумента список чисел и возвращает новый список, в котором остаются только четные числа, отсортированные по возрастанию.

# %% [markdown]
# 5. Напишите функцию, которая принимает в качестве аргумента строку и возвращает новую строку, в которой удалены все гласные буквы.

# %% [markdown]
# 6. Напишите функцию, которая принимает в качестве аргумента список чисел и возвращает произведение всех введенных чисел.

# %% [markdown]
# 7. Напишите функцию, которая принимает в качестве аргумента список строк и возвращает длину самой короткой строки в списке в формате: `Самая короткая строка (<кол-во символов>): <строка>`

# %% [markdown]
# 8. Напишите функцию books(), которая принимает в качестве аргументов словарь с информацией о прочитанных пользователем книгах и печатает информацию об авторе, названии книги и годе выпуска книги (если эти данные введены).
#
# Пример
#
# `books({'Автор': "Михаил Булгаков", 'Любимый_герой': "Маргарита", 'Год': "1929"})` \
# Вывод \
# `Автор книги: Михаил Булгаков \
# Год выхода книги: 1929`
#
# `books({'Книга': "Двенадцать стульев", 'Автор': "Илья Ильф, Евгений Петров", 'Год': "1928", 'Оценка': "5"})` \
# Вывод \
# `Автор книги: Илья Ильф, Евгений Петров \
# Год выхода книги: 1928 \
# Название: Двенадцать стульев`
#
#
# `books({'Год': "1861", 'Книга': "Отцы и дети", 'Оценка': "4", 'Любимый_герой': "Базаров"})` \
# Вывод \
# `Год выхода книги: 1861 \
# Название: Отцы и дети`
